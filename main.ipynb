# %%
pip install tkinter

# %%
from tkinter import *
import mysql.connector

# %%
class LibraryManagementSystem:
    def __init__(self,root):
        self.root = root 
        self.root.title("Library Management System") #Window title
        self.root.geometry("1530x1080+0+0") #Window size
        
        labeltitle = Label(self.root,text = "LIBRARY MANAGEMENT SYSTEM", bg = "light cyan", bd = 10, relief = GROOVE, font = ("Rosewood Std Regular",40,"bold"),padx = 2, pady = 6)
        labeltitle.pack(side = TOP,fill = X)
        
        frame = Frame(self.root,bd = 5, relief = GROOVE,padx = 20, bg = "light cyan")
        frame.place(x=0,y=100,width=1529,height=350)
        
        #------------------------------------------Left Data------------------------------------------
        DataFrameLeft = LabelFrame(frame,text = "Library Membership Information", bg = "light cyan", bd = 3, relief = GROOVE, font = ("times new roman",15,"bold"))
        DataFrameLeft.place(x=0,y=5,width=950,height=320)
        
        labelMember = Label(DataFrameLeft,text = "Member Type",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelMember.grid(row=0,column=0,sticky=W)
        comboMember = ttk.Combobox(DataFrameLeft,font = ("MS Sans Serif",12,"bold"),width = 22,state="readonly")
        comboMember["value"] = ("Admin Staff","Student","Professor")
        comboMember.grid(row=0,column=1)
        
        labelPRN_No = Label(DataFrameLeft,text = "PRN_Number",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelPRN_No.grid(row=1,column=0,sticky=W)
        textPRN_No = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textPRN_No.grid(row=1,column=1)
        
        labelID = Label(DataFrameLeft,text = "ID No",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelID.grid(row=2,column=0,sticky=W)
        textID = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textID.grid(row=2,column=1)
        
        labelFName = Label(DataFrameLeft,text = "First Name",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelFName.grid(row=2,column=0,sticky=W)
        textFName = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textFName.grid(row=2,column=1)
        
        labelLName = Label(DataFrameLeft,text = "Last Name",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelLName.grid(row=3,column=0,sticky=W)
        textLName = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textLName.grid(row=3,column=1)
        
        labelAddress1 = Label(DataFrameLeft,text = "Address1",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelAddress1.grid(row=4,column=0,sticky=W)
        textAddress1 = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textAddress1.grid(row=4,column=1)
        
        labelAddress2 = Label(DataFrameLeft,text = "Address2",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelAddress2.grid(row=5,column=0,sticky=W)
        textAddress2 = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textAddress2.grid(row=5,column=1)
        
        labelPhNo = Label(DataFrameLeft,text = "Phone Number",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelPhNo.grid(row=6,column=0,sticky=W)
        textPhNo = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textPhNo.grid(row=6,column=1)
        
        #--------Column 2-----
        labelBookID = Label(DataFrameLeft,text = "Book ID",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelBookID.grid(row=0,column=2,sticky=W)
        textBookID = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textBookID.grid(row=0,column=3)
        
        labelBookTitle = Label(DataFrameLeft,text = "Book Title",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelBookTitle.grid(row=1,column=2,sticky=W)
        textBookTitle = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textBookTitle.grid(row=1,column=3)
        
        labelAuthor = Label(DataFrameLeft,text = "Author Name",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelAuthor.grid(row=2,column=2,sticky=W)
        textAuthor = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textAuthor.grid(row=2,column=3)
        
        labelBorrowDate = Label(DataFrameLeft,text = "Borrow Date",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelBorrowDate.grid(row=3,column=2,sticky=W)
        textBorrowDate = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textBorrowDate.grid(row=3,column=3)
        
        labelDueDate = Label(DataFrameLeft,text = "Due Date",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelDueDate.grid(row=4,column=2,sticky=W)
        textDueDate = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textDueDate.grid(row=4,column=3)
        
        #labelFine = Label(DataFrameLeft,text = "Late Return Fine",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        #labelFine.grid(row=4,column=2,sticky=W)
        #textFine = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        #textFine.grid(row=4,column=3)
        
        labelOverDue = Label(DataFrameLeft,text = "Date Over Due",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelOverDue.grid(row=5,column=2,sticky=W)
        textOverDue = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textOverDue.grid(row=5,column=3)
        
        labelActPrice = Label(DataFrameLeft,text = "Actual Price",bg = "light cyan",fg="black",font = ("MS Sans Serif",15,"bold"),padx = 2,pady = 6)
        labelActPrice.grid(row=6,column=2,sticky=W)
        textActPrice = Entry(DataFrameLeft,font = ("MS Sans Serif",15,"bold"))
        textActPrice.grid(row=6,column=3)
        
        #--------------------------------------------Data Frame Right ----------------------------------------------
        
        DataFrameRight = LabelFrame(frame,text = "Book Details",fg = "black", bg = "light cyan", bd = 3, relief = GROOVE, font = ("times new roman",15,"bold"))
        DataFrameRight.place(x=975,y=5,width=500,height=320)
        
        self.txtBox = Text(DataFrameRight,font = ("times new roman",15,"bold"),width=22, height=12)
        self.txtBox.grid(row=0,column = 2,padx=4)
        
        listScrollbar = Scrollbar(DataFrameRight)
        listScrollbar.grid(row=0,column=1,sticky="ns")
        
        
        listBooks = ["Introduction to Algorithms","Programming Pearls","Effective Java","Modern PHP","Eloquent Ruby","C# in Depth","C Programming Language","Introduction to Machine Learning","Learn Python 3 the Hard Way","Python for beginners","Machine Learning for beginners","Artificial Intelligence","Operating Systems"]
        listAuthors = ["Thomas H. Cormen","Jon Bentley","Joshua Bloch","Josh Lockhart","Russ Olsen","Jon Skeet","Dennis M. Ritchie","Sarah Guido","Zed A. Shaw","Manya Chaturvedi","Sanya Banerjee","Peter Russel","Henry Silberschatz"] 
        
        listBox = Listbox(DataFrameRight, font = ("MS Sans Serif",15),width=20,height=11)
        listBox.grid(row=0,column=0,padx=4)
        listScrollbar.config(command=listBox.yview)
        
        for item in listBooks:
            listBox.insert(END,item)
        #---------------------------Buttons Frame----------------------------
        Framebutton = Frame(self.root,bd = 5, relief = GROOVE,padx = 1, bg = "light cyan")
        Framebutton.place(x=0,y=460,width=1529,height=80)
        
        buttonAddData = Button(Framebutton, text = "Add Data",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=0)
        
        buttonAddData = Button(Framebutton, text = "Show data",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=1)
        
        buttonAddData = Button(Framebutton, text = "Update",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=2)

        buttonAddData = Button(Framebutton, text = "Delete",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=3)
        
        buttonAddData = Button(Framebutton, text = "Reset",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=4)

        buttonAddData = Button(Framebutton, text = "Exit",font = ("MS Sans Serif",12),width = 27, height = 3,bg = "tomato",fg = "black")
        buttonAddData.grid(row=0,column=5)
                               
        #-----------------Display Frame--------------------
        FrameDetails = Frame(self.root,bd = 5, relief = GROOVE,padx = 10, pady = 10, bg = "light cyan")
        FrameDetails.place(x=0,y=550,width=1529,height=275)

        Table_frame = Frame(FrameDetails,bd=6,relief = GROOVE, bg = "light cyan")
        Table_frame.place(x=0,y=2,width=1491,height=230)
        
        xscroll = ttk.Scrollbar(Table_frame,orient = HORIZONTAL)
        yscroll = ttk.Scrollbar(Table_frame,orient = VERTICAL)
        
        self.library_table = ttk.Treeview(Table_frame,column = ("membertype","prno","firstname","lastname",
                                                                "address1","address2","phonenum","bookid","booktitle",
                                                                "author","borrowdate","duedate","dateoverdue","finalprice"),xscrollcommand = xscroll.set,yscrollcommand = yscroll.set)
        
        xscroll.pack(side=BOTTOM,fill = X)
        yscroll.pack(side = RIGHT, fill = Y)
        
        xscroll.config(command = self.library_table.xview)
        yscroll.config(command = self.library_table.yview)
        
        
        self.library_table.heading("membertype",text = "Member Type")
        self.library_table.heading("prno",text = "PRN_number")
        self.library_table.heading("firstname",text = "First Name")
        self.library_table.heading("lastname",text = "Last Name")
        self.library_table.heading("address1",text = "Address1")
        self.library_table.heading("address2",text = "Address2")
        self.library_table.heading("phonenum",text = "Phone Number")
        self.library_table.heading("bookid",text = "Book ID")
        self.library_table.heading("booktitle",text = "Book Title")
        self.library_table.heading("author",text = "Author Name")
        self.library_table.heading("borrowdate",text = "Borrow Date")
        self.library_table.heading("duedate",text = "Due Date")
        self.library_table.heading("dateoverdue",text = "Date Over Due")
        self.library_table.heading("finalprice",text = "Actual Price")

        self.library_table["show"] = "headings"
        self.library_table.pack(fill=BOTH,expand = 1)
        
        self.library_table.column("membertype",width=110)
        self.library_table.column("prno",width=110)
        self.library_table.column("firstname",width=110)
        self.library_table.column("lastname",width=110)
        self.library_table.column("address1",width=110)
        self.library_table.column("address2",width=110)
        self.library_table.column("phonenum",width=110)
        self.library_table.column("bookid",width=110)
        self.library_table.column("booktitle",width=110)
        self.library_table.column("author",width=110)
        self.library_table.column("borrowdate",width=110)
        self.library_table.column("duedate",width=110)
        self.library_table.column("dateoverdue",width=110)
        self.library_table.column("finalprice",width=110)
        
        
        
        
if __name__  == "__main__":
    root = Tk()
    obj = LibraryManagementSystem(root)
    root.mainloop()
